# %% [markdown]
# # **Welcome to the notebook**

# %% [markdown]
# ### Task 1 - Set up project environment

# %% [markdown]
# Installing the needed modules

# %%
# !pip install openai==1.16.2 python-dotenv
# Out:
# Collecting openai==1.16.2
#   Downloading openai-1.16.2-py3-none-any.whl (267 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 3.8 MB/s eta 0:00:00
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.16.2) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai==1.16.2) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai==1.16.2)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.16.2) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai==1.16.2) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai==1.16.2) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai==1.16.2) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai==1.16.2) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai==1.16.2) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai==1.16.2) (2024.7.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai==1.16.2)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.4 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.16.2)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai==1.16.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai==1.16.2) (2.20.1)
# Installing collected packages: python-dotenv, h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.16.2 python-dotenv-1.0.1

# %% [markdown]
# Importing the needed modules and setup the OpenAI API

# %%
import pandas as pd
import numpy as np
import os
from openai import OpenAI
from dotenv import load_dotenv
from matplotlib import pyplot as plt
import plotly.express as px

from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity

# Loading API key and organization ID from a dotenv file
load_dotenv(dotenv_path='apikey.env.txt')

# Retrieving API key and organization ID from environment variables
APIKEY = os.getenv("APIKEY")

# Creating an instance of the OpenAI client with the provided API key and organization ID
client = OpenAI(
  api_key=APIKEY
)

client

# %% [markdown]
# Import our dataset

# %%
df = pd.read_csv('products_dataset.csv')
df.head()
# Out:
#   product_id                                              title  \
# 0         P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1         P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2         P2                         Large Tapestry Bolster Bed
# 3         P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4         P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                          description
# 0  This heavyweight, water-repellent hooded sweat...
# 1  If you need more length between your existing ...
# 2  Polyester cover resembling rich Italian tapest...
# 3  It features a rectangle shape. This vessel set...
# 4  This 9 in. black full grain leather logger boo...

# %% [markdown]
# List of last 8 products recently viewed by the user.

# %%
searched_products_id = [
    'P1938',
    'P1970',
    'P1044',
    'P1838',
    'P1048',
    'P1017',
    'P1310',
    'P1444',
]

# %% [markdown]
# ### Task 2 - Prepare the dataset

# %% [markdown]
# Let's label the data points that are recently veiwed.

# %%
df['product_status'] = 'not_viewed'
df.loc[df['product_id'].isin(searched_products_id), 'product_status'] = 'recently_viewed'
df[df.product_status == 'recently_viewed']
# Out:
#      product_id                                              title  \
# 1017      P1017  1 qt. #660D-7 Blackberry Farm Satin Enamel Int...
# 1044      P1044  1 qt. #M360-4 Marjoram One-Coat Hide Eggshell ...
# 1048      P1048  5 gal. #640C-1 Hosta Flower Extra Durable Sati...
# 1310      P1310  5 gal. #180A-2 Romantic Morn Extra Durable Sem...
# 1444      P1444  5 gal. #PPU12-17 Cameroon Green Extra Durable ...
# 1838      P1838  5 gal. #N340-2 Dune Grass Extra Durable Satin ...
# 1938      P1938  1 gal. #HDC-SP16-10 Japanese Rose Garden Semi-...
# 1970      P1970  8 oz. #510C-3 Rivers Edge Semi-Gloss Enamel St...
#
#                                             description   product_status
# 1017  Love your space like never before with the hig...  recently_viewed
# 1044  Introducing the best of BEHR Paint. Featuring ...  recently_viewed
# 1048  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1310  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1444  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1838  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1938  Introducing the best of BEHR Paint. Featuring ...  recently_viewed
# 1970  Introducing the best of BEHR Paint. Featuring ...  recently_viewed

# %% [markdown]
# Now let's combine the product `title` and `description` and store it into a column called `combined`.

# %%
df['combined'] = df['title'] + ' ' + df['description']
df.head()
# Out:
#   product_id                                              title  \
# 0         P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1         P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2         P2                         Large Tapestry Bolster Bed
# 3         P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4         P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                          description product_status  \
# 0  This heavyweight, water-repellent hooded sweat...     not_viewed
# 1  If you need more length between your existing ...     not_viewed
# 2  Polyester cover resembling rich Italian tapest...     not_viewed
# 3  It features a rectangle shape. This vessel set...     not_viewed
# 4  This 9 in. black full grain leather logger boo...     not_viewed
#
#                                             combined
# 0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2  Large Tapestry Bolster Bed Polyester cover res...
# 3  16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...

# %% [markdown]
# ### Task 3 - Text embedding and visualization

# %% [markdown]
# Creating the text embedding vectors

# %%
response = client.embeddings.create(
  model="text-embedding-3-small",
  input=df['combined'].tolist(),
  dimensions=512
)
vectors = [d.embedding for d in response.data]
df['text_embedding'] = vectors

# %%
df.head()
# Out:
#   product_id                                              title  \
# 0         P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1         P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2         P2                         Large Tapestry Bolster Bed
# 3         P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4         P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                          description product_status  \
# 0  This heavyweight, water-repellent hooded sweat...     not_viewed
# 1  If you need more length between your existing ...     not_viewed
# 2  Polyester cover resembling rich Italian tapest...     not_viewed
# 3  It features a rectangle shape. This vessel set...     not_viewed
# 4  This 9 in. black full grain leather logger boo...     not_viewed
#
#                                             combined  \
# 0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2  Large Tapestry Bolster Bed Polyester cover res...
# 3  16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                       text_embedding
# 0  [0.042253270745277405, 0.021179627627134323, -...
# 1  [0.04413316026329994, 0.009090634062886238, 0....
# 2  [0.042361605912446976, -0.06515178084373474, 0...
# 3  [-0.049733716994524, -0.011679209768772125, 0....
# 4  [0.026085881516337395, 0.048493191599845886, -...

# %% [markdown]
# > We know that each vector has 512 dimensions. In order to be able to visualize the vectors in a scatter plot, we need to use Principal Component Analysis (PCA) to reduce the dimension from 512 to 2.

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df['text_embedding'].tolist())
pca_result
# Out:
# array([[ 0.00050581, -0.06676073],
#        [-0.36365291, -0.2354297 ],
#        [-0.20928374,  0.21440343],
#        ...,
#        [-0.08170237, -0.10563211],
#        [ 0.50257859, -0.00398109],
#        [-0.27077434,  0.42985076]])

# %%
df['pca1'] = pca_result[:, 0]
df['pca2'] = pca_result[:, 1]
df.head()
# Out:
#   product_id                                              title  \
# 0         P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1         P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2         P2                         Large Tapestry Bolster Bed
# 3         P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4         P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                          description product_status  \
# 0  This heavyweight, water-repellent hooded sweat...     not_viewed
# 1  If you need more length between your existing ...     not_viewed
# 2  Polyester cover resembling rich Italian tapest...     not_viewed
# 3  It features a rectangle shape. This vessel set...     not_viewed
# 4  This 9 in. black full grain leather logger boo...     not_viewed
#
#                                             combined  \
# 0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2  Large Tapestry Bolster Bed Polyester cover res...
# 3  16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                       text_embedding      pca1      pca2
# 0  [0.042253270745277405, 0.021179627627134323, -...  0.000506 -0.066761
# 1  [0.04413316026329994, 0.009090634062886238, 0.... -0.363653 -0.235430
# 2  [0.042361605912446976, -0.06515178084373474, 0... -0.209284  0.214403
# 3  [-0.049733716994524, -0.011679209768772125, 0.... -0.179817 -0.039083
# 4  [0.026085881516337395, 0.048493191599845886, -... -0.212958 -0.143704

# %% [markdown]
# Now that we have the text embedding vectors in two dimensions, we can use them to create a 2D plot.

# %%
px.scatter(df, x='pca1', y='pca2', color='product_status')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id
df.head()
# Out:
#   product_id                                              title  \
# 0         P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1         P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2         P2                         Large Tapestry Bolster Bed
# 3         P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4         P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                          description product_status  \
# 0  This heavyweight, water-repellent hooded sweat...     not_viewed
# 1  If you need more length between your existing ...     not_viewed
# 2  Polyester cover resembling rich Italian tapest...     not_viewed
# 3  It features a rectangle shape. This vessel set...     not_viewed
# 4  This 9 in. black full grain leather logger boo...     not_viewed
#
#                                             combined  \
# 0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2  Large Tapestry Bolster Bed Polyester cover res...
# 3  16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                       text_embedding      pca1      pca2
# 0  [0.042253270745277405, 0.021179627627134323, -...  0.000506 -0.066761
# 1  [0.04413316026329994, 0.009090634062886238, 0.... -0.363653 -0.235430
# 2  [0.042361605912446976, -0.06515178084373474, 0... -0.209284  0.214403
# 3  [-0.049733716994524, -0.011679209768772125, 0.... -0.179817 -0.039083
# 4  [0.026085881516337395, 0.048493191599845886, -... -0.212958 -0.143704

# %% [markdown]
# Get the data related to `recently_viewed` and `not_viewed` products

# %%
df_recently_viewed = df[df.product_status == 'recently_viewed']
df_not_viewed = df[df.product_status == 'not_viewed']

# %% [markdown]
# Convert the embedding vectors to Numpy arrays

# %%
df_recently_viewed
# Out:
#      product_id                                              title  \
# 1017      P1017  1 qt. #660D-7 Blackberry Farm Satin Enamel Int...
# 1044      P1044  1 qt. #M360-4 Marjoram One-Coat Hide Eggshell ...
# 1048      P1048  5 gal. #640C-1 Hosta Flower Extra Durable Sati...
# 1310      P1310  5 gal. #180A-2 Romantic Morn Extra Durable Sem...
# 1444      P1444  5 gal. #PPU12-17 Cameroon Green Extra Durable ...
# 1838      P1838  5 gal. #N340-2 Dune Grass Extra Durable Satin ...
# 1938      P1938  1 gal. #HDC-SP16-10 Japanese Rose Garden Semi-...
# 1970      P1970  8 oz. #510C-3 Rivers Edge Semi-Gloss Enamel St...
#
#                                             description   product_status  \
# 1017  Love your space like never before with the hig...  recently_viewed
# 1044  Introducing the best of BEHR Paint. Featuring ...  recently_viewed
# 1048  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1310  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1444  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1838  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1938  Introducing the best of BEHR Paint. Featuring ...  recently_viewed
# 1970  Introducing the best of BEHR Paint. Featuring ...  recently_viewed
#
#                                                combined  \
# 1017  1 qt. #660D-7 Blackberry Farm Satin Enamel Int...
# 1044  1 qt. #M360-4 Marjoram One-Coat Hide Eggshell ...
# 1048  5 gal. #640C-1 Hosta Flower Extra Durable Sati...
# 1310  5 gal. #180A-2 Romantic Morn Extra Durable Sem...
# 1444  5 gal. #PPU12-17 Cameroon Green Extra Durable ...
# 1838  5 gal. #N340-2 Dune Grass Extra Durable Satin ...
# 1938  1 gal. #HDC-SP16-10 Japanese Rose Garden Semi-...
# 1970  8 oz. #510C-3 Rivers Edge Semi-Gloss Enamel St...
#
#                                          text_embedding      pca1      pca2
# 1017  [0.05918155610561371, -0.02796226739883423, 0....  0.470231  0.057183
# 1044  [0.02989116683602333, -0.02771798148751259, 0....  0.470721  0.046263
# 1048  [0.0008034154889173806, -0.027133531868457794,...  0.457055  0.029323
# 1310  [0.002219964750111103, -0.00657818466424942, 0...  0.466635  0.048867
# 1444  [0.05091223120689392, -0.016536731272935867, 0...  0.464626  0.051656
# 1838  [0.00441074650734663, -0.014054427854716778, 0...  0.459179  0.051007
# 1938  [0.006750619970262051, -0.060344669967889786, ...  0.469535  0.050440
# 1970  [0.03179488703608513, -0.06424853950738907, 0....  0.471998  0.045673

# %%
df_not_viewed
# Out:
#      product_id                                              title  \
# 0            P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1            P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2            P2                         Large Tapestry Bolster Bed
# 3            P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4            P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...         ...                                                ...
# 1995      P1995  Dotty Black and White Black and White Wallpape...
# 1996      P1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997      P1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998      P1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999      P1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                             description product_status  \
# 0     This heavyweight, water-repellent hooded sweat...     not_viewed
# 1     If you need more length between your existing ...     not_viewed
# 2     Polyester cover resembling rich Italian tapest...     not_viewed
# 3     It features a rectangle shape. This vessel set...     not_viewed
# 4     This 9 in. black full grain leather logger boo...     not_viewed
# ...                                                 ...            ...
# 1995  With a stylish monochrome look, this dotty wal...     not_viewed
# 1996  The Abrielle collection features a stunning as...     not_viewed
# 1997  With Fypon balustrade systems, you can transfo...     not_viewed
# 1998  BEHR PREMIUM PLUS Exterior Paint & Primer is a...     not_viewed
# 1999  A refreshing take on innovative designs, Safav...     not_viewed
#
#                                                combined  \
# 0     Men's 3X Large Carbon Heather Cotton/Polyester...
# 1     Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2     Large Tapestry Bolster Bed Polyester cover res...
# 3     16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4     Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...                                                 ...
# 1995  Dotty Black and White Black and White Wallpape...
# 1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                          text_embedding      pca1      pca2
# 0     [0.042253270745277405, 0.021179627627134323, -...  0.000506 -0.066761
# 1     [0.04413316026329994, 0.009090634062886238, 0.... -0.363653 -0.235430
# 2     [0.042361605912446976, -0.06515178084373474, 0... -0.209284  0.214403
# 3     [-0.049733716994524, -0.011679209768772125, 0.... -0.179817 -0.039083
# 4     [0.026085881516337395, 0.048493191599845886, -... -0.212958 -0.143704
# ...                                                 ...       ...       ...
# 1995  [0.09004916995763779, -0.055176541209220886, -... -0.038058  0.195890
# 1996  [0.013627329841256142, -0.04656423255801201, 0... -0.245515  0.483503
# 1997  [-0.029632434248924255, -0.0093860924243927, 0... -0.081702 -0.105632
# 1998  [-0.012979477643966675, -0.00922132097184658, ...  0.502579 -0.003981
# 1999  [-0.007157654967159033, -0.015520446933805943,... -0.270774  0.429851
#
# [1992 rows x 8 columns]

# %%
vectors_recently_viewed = np.array(df_recently_viewed['text_embedding'].tolist())
vectors_not_viewed = np.array(df_not_viewed['text_embedding'].tolist())

# %%
vectors_not_viewed
# Out:
# array([[ 0.04225327,  0.02117963, -0.01352211, ...,  0.0242709 ,
#          0.00989207,  0.04151136],
#        [ 0.04413316,  0.00909063,  0.02689831, ...,  0.04190824,
#         -0.01510124, -0.00232662],
#        [ 0.04236161, -0.06515178,  0.00300138, ...,  0.1061075 ,
#         -0.01914597,  0.07214422],
#        ...,
#        [-0.02963243, -0.00938609,  0.04948691, ..., -0.00773   ,
#         -0.03022956,  0.02616163],
#        [-0.01297948, -0.00922132,  0.04216991, ...,  0.0037894 ,
#         -0.06205868,  0.03520706],
#        [-0.00715765, -0.01552045,  0.07947019, ...,  0.0478956 ,
#         -0.07058661,  0.03291747]])

# %%
vectors_recently_viewed
# Out:
# array([[ 0.05918156, -0.02796227,  0.05370384, ...,  0.03199653,
#         -0.0369931 ,  0.02376145],
#        [ 0.02989117, -0.02771798,  0.05270961, ...,  0.01695084,
#         -0.08368737,  0.05685841],
#        [ 0.00080342, -0.02713353,  0.04528342, ..., -0.00164107,
#         -0.04122982,  0.04933701],
#        ...,
#        [ 0.00441075, -0.01405443,  0.05610869, ..., -0.00937568,
#         -0.03830218,  0.05352857],
#        [ 0.00675062, -0.06034467,  0.04007325, ..., -0.02216943,
#         -0.0787768 ,  0.08100744],
#        [ 0.03179489, -0.06424854,  0.01230332, ..., -0.00732387,
#         -0.02857859,  0.0742462 ]])

# %% [markdown]
# Find the similarity between each viewed product and all the unviewed products.

# %%
similarity_matrix = cosine_similarity(vectors_recently_viewed, vectors_not_viewed)

# %%
similarity_matrix.shape
# Out:
# (8, 1992)

# %%
top_ids = []
for row in similarity_matrix:
  top_id = np.argmax(row)
  top_ids.append(top_id)

top_ids
# Out:
# [854, 1058, 1700, 733, 1323, 1700, 1496, 314]

# %% [markdown]
# ### Task 5 - Recommend products based on the searched products

# %% [markdown]
# Let's update the status of the top similar products to `recommended`.

# %%
most_similar_products = list(df_not_viewed.iloc[top_ids].product_id)

# %%
most_similar_products
# Out:
# ['P854', 'P1061', 'P1705', 'P733', 'P1327', 'P1705', 'P1501', 'P314']

# %% [markdown]
# Let's visualize the recommended products.

# %%
df.loc[df['product_id'].isin(most_similar_products), 'product_status'] = 'recommended'
df[df.product_status == 'recommended']
# Out:
#      product_id                                              title  \
# 314        P314  8 oz. #230F-7 Florence Brown Semi-Gloss Enamel...
# 733        P733  5 gal. #N440-1 Streetwise Extra Durable Semi-G...
# 854        P854  1 qt. #N460-1 Evening White Satin Enamel Inter...
# 1061      P1061  1 gal. #MQ1-28 Orange Flambe One-Coat Hide Egg...
# 1327      P1327  5 gal. #MQ4-44 Green Dynasty Extra Durable Egg...
# 1501      P1501  1 gal. #S-H-620 Midnight Sky Semi-Gloss Enamel...
# 1705      P1705  5 gal. #310D-4 Gold Buff Extra Durable Satin E...
#
#                                             description product_status  \
# 314   Introducing the best of BEHR Paint. Featuring ...    recommended
# 733   BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...    recommended
# 854   Love your space like never before with the hig...    recommended
# 1061  Introducing the best of BEHR Paint. Featuring ...    recommended
# 1327  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...    recommended
# 1501  Introducing the best of BEHR Paint. Featuring ...    recommended
# 1705  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...    recommended
#
#                                                combined  \
# 314   8 oz. #230F-7 Florence Brown Semi-Gloss Enamel...
# 733   5 gal. #N440-1 Streetwise Extra Durable Semi-G...
# 854   1 qt. #N460-1 Evening White Satin Enamel Inter...
# 1061  1 gal. #MQ1-28 Orange Flambe One-Coat Hide Egg...
# 1327  5 gal. #MQ4-44 Green Dynasty Extra Durable Egg...
# 1501  1 gal. #S-H-620 Midnight Sky Semi-Gloss Enamel...
# 1705  5 gal. #310D-4 Gold Buff Extra Durable Satin E...
#
#                                          text_embedding      pca1      pca2
# 314   [-0.003989859018474817, -0.060487765818834305,...  0.493713  0.052178
# 733   [0.009646818973124027, -0.017993971705436707, ...  0.459838  0.004507
# 854   [0.04255978390574455, -0.019562887027859688, 0...  0.491745  0.053064
# 1061  [0.01663183607161045, -0.026091130450367928, 0...  0.496062  0.063849
# 1327  [0.0505719892680645, -0.01987646520137787, 0.0...  0.468602  0.063281
# 1501  [0.020269175991415977, -0.041455335915088654, ...  0.492106  0.039515
# 1705  [-0.002052590949460864, -0.012245520949363708,...  0.460867  0.032166

# %%
px.scatter(df, x='pca1', y='pca2', color='product_status', hover_data=['product_id', 'title'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6cab5c8a-99f3-4c47-a0a9-3f0a7d148003" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6cab5c8a-99f3-4c47-a0a9-3f0a7d148003")) {                    Plotly.newPlot(                        "6cab5c8a-99f3-4c47-a0a9-3f0a7d148003",                        [{"customdata":[["P0","Men's 3X Large Carbon Heather Cotton\u002fPolyester Rain Defender Paxton Heavyweight Hooded Zip-Front Sweatshirt"],["P1","Turmode 30 ft. RP TNC Female to RP TNC Male Adapter Cable"],["P2","Large Tapestry Bolster Bed"],["P3